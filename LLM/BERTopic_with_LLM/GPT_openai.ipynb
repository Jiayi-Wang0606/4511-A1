# %%
# %%capture
# !pip3 install torch==2.2.0

# %%
# %%capture
# !pip install bertopic datasets accelerate openai tiktoken

# %%
import pandas as pd
import numpy as np
import torch
import pickle
import openai
import bertopic
import tiktoken

from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired
from bertopic.representation import OpenAI

# %% [markdown]
# # 1. Load dataset

# %%
loading_dir='./drive/MyDrive/Topic Mining Project/LLM/'

# %%
# 1. load data
class Dataset(torch.utils.data.Dataset):
    def __init__(self):
        self.raw_data = pd.read_json(loading_dir+"data/News_Category_Dataset_v3.json", lines=True)

    def __len__(self):
        return len(self.raw_data)

    def __getitem__(self, i):
        text = self.raw_data['headline'].iloc[i] + ' | ' + self.raw_data['short_description'].iloc[i]
        label = self.raw_data['category'].iloc[i]
        timestamp = self.raw_data['date'].iloc[i]


        return text, label, timestamp


print("loading data...")
dataset = Dataset()
len(dataset)
# Out:
# loading data...
# 209527

# %%
# sample data
documents=dataset[:20000][0]

# %%
timestamp=dataset[:20000][2]

# %% [markdown]
# # 2. Load OpenAI API
# - prompt
# - tokenizer

# %%
prompt=None

# %%
tokenizer= tiktoken.encoding_for_model("gpt-3.5-turbo")
# Create your representation model
client = openai.OpenAI(api_key="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")
openai_model = OpenAI(
    client,
    model="gpt-3.5-turbo",
    delay_in_seconds=1,
    prompt=prompt,
    chat=True,
    nr_docs=20, # we send 4 docs to GPT API at one time
    doc_length=500,
    tokenizer=tokenizer
)

# %% [markdown]
# # 3. other submodels

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer_model=CountVectorizer(stop_words="english")

# %%
from sentence_transformers import SentenceTransformer
# Pre-calculate embeddings
embedding_model = SentenceTransformer("BAAI/bge-small-en")
embeddings = embedding_model.encode(documents,show_progress_bar=True)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/90.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/684 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/625 [00:00<?, ?it/s]

# %%
from umap import UMAP
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine', random_state=42)

# %%
# Pre-reduce embeddings for visualization purposes
reduced_embeddings = UMAP(n_neighbors=15, n_components=2, min_dist=0.0, metric='cosine', random_state=42).fit_transform(embeddings)

# %%
from hdbscan import HDBSCAN
hdbscan_model = HDBSCAN(min_cluster_size=100, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

from sklearn.cluster import KMeans
kmeans_model = KMeans(n_clusters=100)

# %% [markdown]
# # 4. Fit model

# %%
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance

# KeyBERT
keybert = KeyBERTInspired()
# MMR
# mmr = MaximalMarginalRelevance(diversity=0.3)

# All representation models
representation_model = {
    "KeyBERT": keybert,
    "Openai": openai_model,
    # "MMR": mmr,
}

# %%
from bertopic import BERTopic

topic_model = BERTopic(

  # Sub-models
  vectorizer_model=vectorizer_model,
  embedding_model=embedding_model,
  umap_model=umap_model,
  hdbscan_model=kmeans_model,
  representation_model=representation_model,

  # Hyperparameters
  top_n_words=10,
  verbose=True,
  nr_topics=100, # if nr_topics>n_clusters, will combine similar clusters to reduce number
)

# Train model
topics, probs = topic_model.fit_transform(documents, embeddings)
# Out:
# 2024-03-04 12:00:09,724 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-03-04 12:00:31,417 - BERTopic - Dimensionality - Completed ✓
# 2024-03-04 12:00:31,419 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-03-04 12:00:32,977 - BERTopic - Cluster - Completed ✓
# 2024-03-04 12:00:32,978 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 100%|██████████| 100/100 [03:20<00:00,  2.01s/it]
# 2024-03-04 12:03:58,396 - BERTopic - Representation - Completed ✓
# 2024-03-04 12:03:58,397 - BERTopic - Topic reduction - Reducing number of topics
# 2024-03-04 12:03:58,402 - BERTopic - Topic reduction - Reduced number of topics from 100 to 100

# %%
# Show topics
topic_model.get_topic_info()
# Out:
#     Topic  Count                               Name  \
# 0       0     92    0_capitol_riot_jan_insurrection
# 1       1    127     1_olympic_olympics_tennis_gold
# 2       2    187    2_police_officer_floyd_officers
# 3       3    202    3_pandemic_coronavirus_covid_19
# 4       4    137        4_netflix_watch_movies_week
# ..    ...    ...                                ...
# 95     95     56    95_funniest_tweets_parents_week
# 96     96    117   96_voting_democrats_rights_voter
# 97     97     83     97_workers_starbucks_tax_union
# 98     98     15  98_opioid_purdue_pharma_oxycontin
# 99     99     56               99_dogs_cats_cat_dog
#
#                                        Representation  \
# 0   [capitol, riot, jan, insurrection, attack, rio...
# 1   [olympic, olympics, tennis, gold, medal, tokyo...
# 2   [police, officer, floyd, officers, man, trial,...
# 3   [pandemic, coronavirus, covid, 19, face, mask,...
# 4   [netflix, watch, movies, week, popular, movie,...
# ..                                                ...
# 95  [funniest, tweets, parents, week, kids, aug, j...
# 96  [voting, democrats, rights, voter, census, vot...
# 97  [workers, starbucks, tax, union, pay, cuts, am...
# 98  [opioid, purdue, pharma, oxycontin, walgreens,...
# 99  [dogs, cats, cat, dog, funniest, tweets, week,...
#
#                                               KeyBERT  \
# 0   [insurrectionists, rioters, insurrection, capi...
# 1   [olympics, olympic, athlete, olympian, athlete...
# 2   [killed, manslaughter, prosecutor, accused, ar...
# 3   [masks, pandemic, coronavirus, distancing, cov...
# 4   [netflix, movies, hbo, movie, debuts, comedies...
# ..                                                ...
# 95  [tweets, funniest, parents, parenting, funny, ...
# 96  [democrats, voting, filibuster, gerrymandering...
# 97  [union, workers, starbucks, unionize, labor, s...
# 98  [pharmacies, pharma, oxycontin, walgreens, opi...
# 99  [cats, tweets, funniest, cat, hilarious, pets,...
#
#                                                Openai  \
# 0           [Capitol Riot and Insurrection Aftermath]
# 1   [Olympic Updates and Controversies from Tokyo ...
# 2   [Police Officer Misconduct and Civil Rights Vi...
# 3   [Coping with COVID-19 Pandemic and Face Mask A...
# 4   [Netflix's Popular Movie Releases and Trending...
# ..                                                ...
# 95  [Funniest Parent Tweets of the Week on Kids an...
# 96  [Voting Rights and Democrats' Legislative Effo...
# 97  [Labor and Corporate Actions in the Face of Ec...
# 98  [Opioid Crisis and Legal Actions Against Purdu...
# 99              [Funniest tweets about cats and dogs]
#
#                                   Representative_Docs
# 0   [Capitol Police Fence Off Capitol Ahead of Bid...
# 1   [Mikaela Shiffrin Sets Fastest Time In Downhil...
# 2   [Lawyer For Derek Chauvin Claims Settlement Pa...
# 3   [How To Clean A Fabric Coronavirus Face Mask A...
# 4   [What To Watch On Netflix That’s New This Week...
# ..                                                ...
# 95  [The Funniest Tweets From Parents This Week (A...
# 96  [Obama: Senate Should Eliminate Filibuster To ...
# 97  [Another Starbucks Store Votes To Unionize | T...
# 98  [OxyContin Maker Purdue Pharma Files For Bankr...
# 99  [23 Of The Funniest Tweets About Cats And Dogs...
#
# [100 rows x 7 columns]

# %% [markdown]
# # Visualization

# %%
topic_model.visualize_documents(dataset[:10000][0], reduced_embeddings=reduced_embeddings[:], hide_annotations=True, hide_document_hover=False, custom_labels=True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
topics_over_time = topic_model.topics_over_time(documents, timestamp, nr_bins=20)
topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="058bacbb-e7c2-4da6-b478-e99b689de26f" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("058bacbb-e7c2-4da6-b478-e99b689de26f")) {                    Plotly.newPlot(                        "058bacbb-e7c2-4da6-b478-e99b689de26f",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: black, men, cop, man, police","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: police, officer, bernstein, officers, action","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: hate, crime, man, murder, utah","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: execution, row, dozier, stephon, insisting","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: officer, hamas, app, darden, deliberation","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: officer, police, officers, roberts, murder","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: botham, police, hate, officer, allegedly","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: quilt, officers, panhandling, dylann, police","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: logan, officer, players, charged, riep","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: floyd, police, officer, george, protester","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: mcclain, elijah, cop, police, filed","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: kidnap, enslaved, michigan, robbed, plotted","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: police, walker, kenneth, charged, cop","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: floyd, chauvin, derek, george, trial","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: cops, sleuths, identified, plea, vel\u00e1squez","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: ahmaud, arbery, prosecutor, men, blake","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: jury, officer, trial, rittenhouse, potter","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: arbery, ahmaud, officers, minneapolis, killing","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: supermarket, buffalo, dispatcher, shooter, gunfire","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: police, baltimore, louisville, murder, taylor"],"marker":{"color":"#E69F00"},"mode":"lines","name":"2_police_officer_floyd_officers","x":["2018-04-29T09:27:21.600000","2018-07-20T07:12:00","2018-10-08T14:24:00","2018-12-27T21:36:00","2019-03-18T04:48:00","2019-06-06T12:00:00","2019-08-25T19:12:00","2019-11-14T02:24:00","2020-02-02T09:36:00","2020-04-22T16:48:00","2020-07-12T00:00:00","2020-09-30T07:12:00","2020-12-19T14:24:00","2021-03-09T21:36:00","2021-05-29T04:48:00","2021-08-17T12:00:00","2021-11-05T19:12:00","2022-01-25T02:24:00","2022-04-15T09:36:00","2022-07-04T16:48:00"],"y":[20,9,6,2,5,15,14,3,4,12,5,2,13,21,5,12,13,10,4,12],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: shadows, deserves, anxiety, attention, remains","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: reshma, gopaldas, boob, breast, squad","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: shower, sweats, awash, fatigue, bacteria","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: coronavirus, pandemic, covid, 19, distancing","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: pandemic, coronavirus, face, mask, covid","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: pandemic, 19, covid, coronavirus, face","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: pan ...

# %%
topics_per_class = topic_model.topics_per_class(documents, classes=dataset[:10000][1])
topic_model.visualize_topics_per_class(topics_per_class, top_n_topics=10)
# Out:
# 29it [00:02, 11.26it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="29cd0724-1f36-4aec-9a43-e44ea7ff2ebb" class="plotly-graph-div" style="height:900px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29cd0724-1f36-4aec-9a43-e44ea7ff2ebb")) {                    Plotly.newPlot(                        "29cd0724-1f36-4aec-9a43-e44ea7ff2ebb",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: police, man, arbery, officer, trial","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: men, caught, zuley, zashy, faggot","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: savarino, krzyzewski, paolo, internally, banchero","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: murder, girl, convicted, sentenced, raped","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: police, floyd, officer, george, man","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: thug, racketeering, case, gang, stewart","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: police, officers, officer, floyd, trial","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: officer, floyd, police, black, pittsburgh"],"marker":{"color":"#E69F00"},"name":"2_police_officer_floyd_officers","orientation":"h","visible":true,"x":[38,4,1,7,39,4,81,13],"y":["CRIME","QUEER VOICES","SPORTS","WORLD NEWS","POLITICS","ENTERTAINMENT","U.S. NEWS","BLACK VOICES"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: reshma, gopaldas, boob, breast, squad","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: means, queens, drag, synching, performances","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: insiders, bloopers, pandemic, hilarious, reporters","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: bbl, patients, pandemic, blur, sufficient","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: mask, face, coronavirus, pandemic, covid","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: leagues, eager, worsening, prepared, baseball","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: montreal, equipment, pandemic, heartening, chinatown","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: pandemic, breastfeeding, covid, 19, coronavirus","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: pandemic, coronavirus, crisis, covid, 19","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: enrollment, wanes, rebound, wondering, dips","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: pandemic, networks, coronavirus, covid, eardrum","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: journalism, industry, shifting, crushing, receptive","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: pandemic, coronavirus, covid, 19, experts","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: pandemic, escapist, coronavirus, wear, distancing","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: pandemic, coronavirus, covid, 19, cancellations","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: or2, asteroid, approaching, 1998, researchers","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: shutting, weight, pandemic, disconnects, layoff","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: panic, buying, stockpiling, pasta, canned","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: pandemic, coronavirus, covid, 19, restaurants","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: pandemic, coronavirus, sobering, lehman, inequalities","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: safer, road, pandemic, trip, coronavirus"],"marker":{"color":"#56B4E9"},"name" ...

# %%
topic_distr, _ = topic_model.approximate_distribution(documents)
topic_model.visualize_distribution(topic_distr[10])
# Out:
# 100%|██████████| 10/10 [00:06<00:00,  1.63it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f639ba40-876f-4497-afcf-6875e5450e54" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f639ba40-876f-4497-afcf-6875e5450e54")) {                    Plotly.newPlot(                        "f639ba40-876f-4497-afcf-6875e5450e54",                        [{"marker":{"color":"#C8D2D7","line":{"color":"#6E8484","width":1}},"orientation":"h","x":[0.33952999258873795,0.08894316332410705,0.09333564601963527,0.2961929853874672,0.18199821268005253],"y":["\u003cb\u003eTopic 50\u003c\u002fb\u003e: nfl_quarterback_bowl_su...","\u003cb\u003eTopic 58\u003c\u002fb\u003e: democratic_primary_camp...","\u003cb\u003eTopic 63\u003c\u002fb\u003e: space_cave_nasa_moon_ro...","\u003cb\u003eTopic 93\u003c\u002fb\u003e: saudi_arabia_khashoggi_...","\u003cb\u003eTopic 96\u003c\u002fb\u003e: voting_democrats_rights..."],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0. ...

# %%
# Calculate the topic distributions on a token-level
topic_distr, topic_token_distr = topic_model.approximate_distribution(documents, calculate_tokens=True)

# Visualize the token-level distributions
df = topic_model.visualize_approximate_distribution(documents[10], topic_token_distr[10])
df
# Out:
# 100%|██████████| 10/10 [00:05<00:00,  1.71it/s]
# <style type="text/css">
# #T_82b80_row0_col0, #T_82b80_row0_col1, #T_82b80_row0_col2, #T_82b80_row0_col3, #T_82b80_row2_col15, #T_82b80_row2_col16, #T_82b80_row2_col17, #T_82b80_row2_col18 {
#   background-color: #b2d2e8;
#   color: #000000;
#   color: black;
# }
# #T_82b80_row0_col4, #T_82b80_row0_col5, #T_82b80_row0_col6, #T_82b80_row0_col7, #T_82b80_row0_col8, #T_82b80_row0_col9, #T_82b80_row0_col10, #T_82b80_row0_col11, #T_82b80_row0_col12, #T_82b80_row0_col13, #T_82b80_row0_col14, #T_82b80_row0_col19, #T_82b80_row0_col20, #T_82b80_row0_col21, #T_82b80_row0_col22, #T_82b80_row0_col23, #T_82b80_row0_col24, #T_82b80_row0_col25, #T_82b80_row0_col26, #T_82b80_row0_col27, #T_82b80_row0_col28, #T_82b80_row1_col0, #T_82b80_row1_col1, #T_82b80_row1_col2, #T_82b80_row1_col3, #T_82b80_row1_col4, #T_82b80_row1_col5, #T_82b80_row1_col6, #T_82b80_row1_col7, #T_82b80_row1_col8, #T_82b80_row1_col9, #T_82b80_row1_col10, #T_82b80_row1_col11, #T_82b80_row1_col12, #T_82b80_row1_col13, #T_82b80_row1_col14, #T_82b80_row1_col15, #T_82b80_row1_col16, #T_82b80_row1_col17, #T_82b80_row1_col18, #T_82b80_row1_col19, #T_82b80_row1_col20, #T_82b80_row1_col21, #T_82b80_row1_col22, #T_82b80_row1_col27, #T_82b80_row1_col28, #T_82b80_row1_col29, #T_82b80_row1_col30, #T_82b80_row1_col31, #T_82b80_row1_col32, #T_82b80_row2_col0, #T_82b80_row2_col1, #T_82b80_row2_col2, #T_82b80_row2_col3, #T_82b80_row2_col4, #T_82b80_row2_col5, #T_82b80_row2_col6, #T_82b80_row2_col7, #T_82b80_row2_col8, #T_82b80_row2_col9, #T_82b80_row2_col10, #T_82b80_row2_col11, #T_82b80_row2_col12, #T_82b80_row2_col13, #T_82b80_row2_col14, #T_82b80_row2_col19, #T_82b80_row2_col20, #T_82b80_row2_col21, #T_82b80_row2_col22, #T_82b80_row2_col23, #T_82b80_row2_col24, #T_82b80_row2_col25, #T_82b80_row2_col26, #T_82b80_row2_col27, #T_82b80_row2_col28, #T_82b80_row2_col29, #T_82b80_row2_col30, #T_82b80_row2_col31, #T_82b80_row2_col32, #T_82b80_row3_col0, #T_82b80_row3_col1, #T_82b80_row3_col2, #T_82b80_row3_col3, #T_82b80_row3_col4, #T_82b80_row3_col5, #T_82b80_row3_col6, #T_82b80_row3_col7, #T_82b80_row3_col8, #T_82b80_row3_col9, #T_82b80_row3_col10, #T_82b80_row3_col11, #T_82b80_row3_col12, #T_82b80_row3_col13, #T_82b80_row3_col14, #T_82b80_row3_col15, #T_82b80_row3_col16, #T_82b80_row3_col17, #T_82b80_row3_col18, #T_82b80_row3_col19, #T_82b80_row3_col20, #T_82b80_row3_col21, #T_82b80_row3_col28, #T_82b80_row3_col29, #T_82b80_row3_col30, #T_82b80_row3_col31, #T_82b80_row3_col32, #T_82b80_row4_col0, #T_82b80_row4_col1, #T_82b80_row4_col2, #T_82b80_row4_col3, #T_82b80_row4_col4, #T_82b80_row4_col5, #T_82b80_row4_col6, #T_82b80_row4_col7, #T_82b80_row4_col8, #T_82b80_row4_col9, #T_82b80_row4_col10, #T_82b80_row4_col11, #T_82b80_row4_col12, #T_82b80_row4_col13, #T_82b80_row4_col14, #T_82b80_row4_col15, #T_82b80_row4_col16, #T_82b80_row4_col17, #T_82b80_row4_col18, #T_82b80_row4_col19, #T_82b80_row4_col20, #T_82b80_row4_col21, #T_82b80_row4_col28, #T_82b80_row4_col29, #T_82b80_row4_col30, #T_82b80_row4_col31, #T_82b80_row4_col32 {
#   background-color: #f7fbff;
#   color: #000000;
#   color: white;
#   background-color: white;
# }
# #T_82b80_row0_col15, #T_82b80_row0_col16, #T_82b80_row0_col17, #T_82b80_row0_col18, #T_82b80_row3_col27 {
#   background-color: #a6cee4;
#   color: #000000;
#   color: black;
# }
# #T_82b80_row0_col29, #T_82b80_row0_col30, #T_82b80_row0_col31, #T_82b80_row0_col32 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
#   color: black;
# }
# #T_82b80_row1_col23, #T_82b80_row1_col24, #T_82b80_row1_col25, #T_82b80_row1_col26 {
#   background-color: #b7d4ea;
#   color: #000000;
#   color: black;
# }
# #T_82b80_row3_col22 {
#   background-color: #add0e6;
#   color: #000000;
#   color: black;
# }
# #T_82b80_row3_col23 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
#   color: black;
# }
# #T_82b80_row3_col24, #T_82b80_row3_col25 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   color: black;
# }
# #T_82b80_row3_col26 {
#   background-color: #3686c0;
#   color: #f1f1f1;
#   color: black;
# }
# #T_82b80_row4_col22, #T_82b80_row4_col23 {
#   background-color: #b4d3e9;
#   color: #000000;
#   color: black;
# }
# #T_82b80_row4_col24, #T_82b80_row4_col25 {
#   background-color: #4594c7;
#   color: #f1f1f1;
#   color: black;
# }
# #T_82b80_row4_col26, #T_82b80_row4_col27 {
#   background-color: #b3d3e8;
#   color: #000000;
#   color: black;
# }
# </style>
# <table id="T_82b80" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82b80_level0_col0" class="col_heading level0 col0" >World</th>
#       <th id="T_82b80_level0_col1" class="col_heading level0 col1" >Cup </th>
#       <th id="T_82b80_level0_col2" class="col_heading level0 col2" >Captains  </th>
#       <th id="T_82b80_level0_col3" class="col_heading level0 col3" >Want   </th>
#       <th id="T_82b80_level0_col4" class="col_heading level0 col4" >To    </th>
#       <th id="T_82b80_level0_col5" class="col_heading level0 col5" >Wear     </th>
#       <th id="T_82b80_level0_col6" class="col_heading level0 col6" >Rainbow      </th>
#       <th id="T_82b80_level0_col7" class="col_heading level0 col7" >Armbands       </th>
#       <th id="T_82b80_level0_col8" class="col_heading level0 col8" >In        </th>
#       <th id="T_82b80_level0_col9" class="col_heading level0 col9" >Qatar         </th>
#       <th id="T_82b80_level0_col10" class="col_heading level0 col10" >FIFA          </th>
#       <th id="T_82b80_level0_col11" class="col_heading level0 col11" >has           </th>
#       <th id="T_82b80_level0_col12" class="col_heading level0 col12" >come            </th>
#       <th id="T_82b80_level0_col13" class="col_heading level0 col13" >under             </th>
#       <th id="T_82b80_level0_col14" class="col_heading level0 col14" >pressure              </th>
#       <th id="T_82b80_level0_col15" class="col_heading level0 col15" >from               </th>
#       <th id="T_82b80_level0_col16" class="col_heading level0 col16" >several                </th>
#       <th id="T_82b80_level0_col17" class="col_heading level0 col17" >European                 </th>
#       <th id="T_82b80_level0_col18" class="col_heading level0 col18" >soccer                  </th>
#       <th id="T_82b80_level0_col19" class="col_heading level0 col19" >federations                   </th>
#       <th id="T_82b80_level0_col20" class="col_heading level0 col20" >who                    </th>
#       <th id="T_82b80_level0_col21" class="col_heading level0 col21" >want                     </th>
#       <th id="T_82b80_level0_col22" class="col_heading level0 col22" >to                      </th>
#       <th id="T_82b80_level0_col23" class="col_heading level0 col23" >support                       </th>
#       <th id="T_82b80_level0_col24" class="col_heading level0 col24" >human                        </th>
#       <th id="T_82b80_level0_col25" class="col_heading level0 col25" >rights                         </th>
#       <th id="T_82b80_level0_col26" class="col_heading level0 col26" >campaign                          </th>
#       <th id="T_82b80_level0_col27" class="col_heading level0 col27" >against                           </th>
#       <th id="T_82b80_level0_col28" class="col_heading level0 col28" >discrimination                            </th>
#       <th id="T_82b80_level0_col29" class="col_heading level0 col29" >at                             </th>
#       <th id="T_82b80_level0_col30" class="col_heading level0 col30" >the                              </th>
#       <th id="T_82b80_level0_col31" class="col_heading level0 col31" >World                               </th>
#       <th id="T_82b80_level0_col32" class="col_heading level0 col32" >Cup                                </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82b80_level0_row0" class="row_heading level0 row0" >50_nfl_quarterback_bowl_super</th>
#       <td id="T_82b80_row0_col0" class="data row0 col0" >0.106</td>
#       <td id="T_82b80_row0_col1" class="data row0 col1" >0.106</td>
#       <td id="T_82b80_row0_col2" class="data row0 col2" >0.106</td>
#       <td id="T_82b80_row0_col3" class="data row0 col3" >0.106</td>
#       <td id="T_82b80_r

# %%
from scipy.cluster import hierarchy as sch
# Hierarchical topics
linkage_function = lambda x: sch.linkage(x, 'single', optimal_ordering=True)
hierarchical_topics = topic_model.hierarchical_topics(documents, linkage_function=linkage_function)
topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0e682df4-eb03-451a-839e-7672de8e06fc" class="plotly-graph-div" style="height:1700px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e682df4-eb03-451a-839e-7672de8e06fc")) {                    Plotly.newPlot(                        "0e682df4-eb03-451a-839e-7672de8e06fc",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["actor_smith_theron_reynolds_star","","","friends_smith_pinkett_star_jennifer"],"x":[0.0,0.6730829332938358,0.6730829332938358,0.0],"xaxis":"x","y":[-25.0,-25.0,-35.0,-35.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["awards_film_queer_cannes_oscars","","","actor_smith_star_pinkett_chris"],"x":[0.0,0.7499170975579199,0.7499170975579199,0.6730829332938358],"xaxis":"x","y":[-15.0,-15.0,-30.0,-30.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["awards_film_queer_cannes_oscars","","","wars_marvel_star_boseman_film"],"x":[0.7499170975579199,0.8009808442383298,0.8009808442383298,0.0],"xaxis":"x","y":[-22.5,-22.5,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","text":["netflix_watch_movies_week_popular","","","star_actor_film_smith_movie"],"x":[0.0,0.9086573927823532,0.9086573927823532,0.8009808442383298],"xaxis":"x","y":[-5.0,-5.0,-33.75,-33.75],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["rapper_singer_kelly_kanye_west","","","singer_spears_music_britney_song"],"x":[0.0,0.6432856691429072,0.6432856691429072,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["kardashian_kim_jenner_lopez_gala","","","teigen_chrissy_ellen_baby_degeneres"],"x":[0.0,0.7863005577055423,0.7863005577055423,0.0],"xaxis":"x","y":[-75.0,-75.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(255,65,54)"},"mode":"lines","text":["singer_rapper_music_spears_song","","","teigen_chrissy_ellen_baby_degeneres"],"x":[0.6432856691429072,0.8932509087824818,0.8932509087824818,0.7863005577055423],"xaxis":"x","y":[-60.0,-60.0,-80.0,-80.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","text":["singer_rapper_music_spears_song","","","teigen_chrissy_ellen_baby_degeneres"],"x":[0.9086573927823532,1.0441048140341984,1.0441048140341984,0.8932509087824818],"xaxis":"x","y":[-19.375,-19.375,-70.0,-70.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["mosque_zealand_christchurch_ardern_jacinda","","","jewish_groups_jews_pittsburgh_semitism"],"x":[0.0,0.8293204037839624,0.8293204037839624,0.0],"xaxis":"x","y":[-95.0,-95.0,-105.0,-105.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["man_police_old_missing_body","","","police_officer_floyd_officers_man"],"x":[0.0,0.6572997533017055,0.6572997533017055,0.0],"xaxis":"x","y":[-115.0,-115.0,-125.0,-125.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["shooting_police_killed_dead_gunman","","","school_shooting_uvalde_gun_parkland"],"x":[0.0,0.5920597583288754,0.5920597583288754,0.0],"xaxis":"x","y":[-135.0,-135.0,-145.0,-145.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(35,205,205)"},"mode":"lines","text":["shooting_police_killed_dead_gunman","","","shooting_school_police_killed_shot"],"x":[0.6572997533017055,0.7419381904280915,0.7419381 ...

# %%
embedding_model = "sentence-transformers/BAAI/bge-small-en"
topic_model.save(loading_dir+"GPTopenai", serialization="safetensors", save_ctfidf=True, save_embedding_model=embedding_model)

# %%
loaded_model = BERTopic.load(loading_dir+"saved_model")

# %%
loaded_model.get_topic_info()
# Out:
#     Topic  Count                                       Name  \
# 0       0    926                0_autism_child_autistic_son
# 1       1   2196                   1_trump_comey_fbi_russia
# 2       2   3209                  2_music_song_songs_singer
# 3       3   2127           3_travel_vacation_traveling_trip
# 4       4   1437        4_abortion_court_parenthood_planned
# ..    ...    ...                                        ...
# 95     95   3123               95_cancer_health_mental_care
# 96     96   2411  96_church_confederate_charlottesville_god
# 97     97   1918             97_netflix_thrones_season_game
# 98     98   1845                    98_cruz_rubio_ted_marco
# 99     99     22              99_bliss_oxygen_teamed_triple
#
#                                        Representation  \
# 0   [autism, child, autistic, son, syndrome, disab...
# 1   [trump, comey, fbi, russia, mueller, probe, ho...
# 2   [music, song, songs, singer, band, rapper, alb...
# 3   [travel, vacation, traveling, trip, road, trav...
# 4   [abortion, court, parenthood, planned, supreme...
# ..                                                ...
# 95  [cancer, health, mental, care, patients, illne...
# 96  [church, confederate, charlottesville, god, je...
# 97  [netflix, thrones, season, game, walking, trai...
# 98  [cruz, rubio, ted, marco, jeb, carson, bush, c...
# 99  [bliss, oxygen, teamed, triple, luck, tip, sep...
#
#                                               KeyBERT  \
# 0   [autism, asperger, autistic, asd, parenting, t...
# 1   [comey, trump, reportedly, bannon, wikileaks, ...
# 2   [music, song, musician, songs, spotify, album,...
# 3   [traveling, travel, travelers, travels, travel...
# 4   [abortion, abortions, scotus, republicans, jus...
# ..                                                ...
# 95  [cancer, health, care, medicine, patients, che...
# 96  [charlottesville, christians, confederate, chr...
# 97  [hbo, thrones, spoilers, tv, spoiler, episodes...
# 98  [rubio, cruz, republicans, nonpartisan, gop, t...
# 99                               [, , , , , , , , , ]
#
#                                                Llama2  Representative_Docs
# 0                          [Autism, , , , , , , , , ]                  NaN
# 1            [Russia Investigation, , , , , , , , , ]                  NaN
# 2                           [Music, , , , , , , , , ]                  NaN
# 3                          [Travel, , , , , , , , , ]                  NaN
# 4   [Reproductive Rights and Access to Abortion, ,...                  NaN
# ..                                                ...                  ...
# 95      [Cancer Care and Treatment, , , , , , , , , ]                  NaN
# 96    [Religion and Social Justice, , , , , , , , , ]                  NaN
# 97                [Game of Thrones, , , , , , , , , ]                  NaN
# 98               [GOP Primary Race, , , , , , , , , ]                  NaN
# 99           [Blissful Oxygen Tips, , , , , , , , , ]                  NaN
#
# [100 rows x 7 columns]
