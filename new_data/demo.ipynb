# %%
# %%capture
# !pip3 install torch==2.2.0

# %%
# %%capture
# !pip install bertopic datasets accelerate openai tiktoken schedule

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
loading_dir='/content/drive/MyDrive/Topic Mining Project/new_data/'
sys.path.append(loading_dir)

# %%
import run_model_daily
import update_data_hourly
import schedule
import time

def hourly_task():
  print('updating data...')
  update_data_hourly.update_data()


def daily_task():
  print('updating model...')
  run_model_daily.run_model()

schedule.every().hour.do(hourly_task)
schedule.every().day.at("00:00").do(daily_task)

while True:
    schedule.run_pending()
    time.sleep(600)
